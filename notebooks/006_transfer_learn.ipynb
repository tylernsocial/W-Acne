# %% [markdown]
# Now we will try to use transfer learning which is a model that was already trained on a huge image dataset and then adapt it to the smaller acne dataset
#
# basically instead of the model learning everything from 0 like we have been doing it will start pre-existing knowledge, such as, edges, colours, textures, curves, shapes, smaller patterns, and surface details
#
# Will try to use MobileNetV2 which is a lightweight pretrained CNN and commonly used for image classification
#
# How it works MNV2 works, it can be seen as two parts, pretrainted feature extractor + custom classifier
#
# the pretrained part will look at the imnage and extract useful features
#
# the custom classifier takes those features and predict one of the classes
#
# Need to freeze the base model which is MNV2, and freezing is not updated the pretrained models weights during training, this needs to be done specifically here since MNV2 already learned useful image features so if train everything immediately on the small dataset it might lose those learn features

# %%
from pathlib import Path
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
PROJECT_ROOT = Path("..")
PROCESSED_DIR = PROJECT_ROOT / "data" / "processed"

train_df = pd.read_csv(PROCESSED_DIR / "train.csv")
val_df = pd.read_csv(PROCESSED_DIR / "val.csv")
test_df = pd.read_csv(PROCESSED_DIR / "test.csv")

train_df.head()
# Out:
#                                original_path  \
# 0        ..\data\raw\acne_scars\scar_026.png
# 1  ..\data\raw\comedonal_closed\come_022.png
# 2   ..\data\raw\comedonal_open\comeo_035.png
# 3        ..\data\raw\acne_scars\scar_050.png
# 4  ..\data\raw\comedonal_closed\come_021.png
#
#                                       processed_path             label
# 0   ..\data\processed\acne_scars\acne_scars_0026.jpg        acne_scars
# 1  ..\data\processed\comedonal_closed\comedonal_c...  comedonal_closed
# 2  ..\data\processed\comedonal_open\comedonal_ope...    comedonal_open
# 3   ..\data\processed\acne_scars\acne_scars_0050.jpg        acne_scars
# 4  ..\data\processed\comedonal_closed\comedonal_c...  comedonal_closed

# %%
class_names = sorted(train_df["label"].unique())
label_to_index = {label: index for index, label in enumerate(class_names)}

train_df["label_index"] = train_df["label"].map(label_to_index)
val_df["label_index"] = val_df["label"].map(label_to_index)
test_df["label_index"] = test_df["label"].map(label_to_index)

class_names, label_to_index
# Out:
# (['acne_scars', 'comedonal_closed', 'comedonal_open', 'inflammatory_acne'],
#  {'acne_scars': 0,
#   'comedonal_closed': 1,
#   'comedonal_open': 2,
#   'inflammatory_acne': 3})

# %%
train_paths = train_df["processed_path"].values
val_paths = val_df["processed_path"].values
test_paths = test_df["processed_path"].values

train_labels = train_df["label_index"].values
val_labels = val_df["label_index"].values
test_labels = test_df["label_index"].values

# %%
IMG_SIZE = 224
BATCH_SIZE = 16

def load_image_for_mobilenet(image_path, label):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image = tf.keras.applications.mobilenet_v2.preprocess_input(image)
    return image, label

# %%
train_ds = tf.data.Dataset.from_tensor_slices((train_paths, train_labels))
val_ds = tf.data.Dataset.from_tensor_slices((val_paths, val_labels))
test_ds = tf.data.Dataset.from_tensor_slices((test_paths, test_labels))

train_ds = train_ds.map(load_image_for_mobilenet)
val_ds = val_ds.map(load_image_for_mobilenet)
test_ds = test_ds.map(load_image_for_mobilenet)

train_ds = train_ds.shuffle(buffer_size=len(train_df)).batch(BATCH_SIZE)
val_ds = val_ds.batch(BATCH_SIZE)
test_ds = test_ds.batch(BATCH_SIZE)

# %%
## still going to use the gentle data augmentation
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.03),
    tf.keras.layers.RandomZoom(0.05),
])

# %%
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights="imagenet"
)

base_model.trainable = False

# %%
num_classes = len(class_names)

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(224, 224, 3)),
    data_augmentation,

    base_model,

    tf.keras.layers.GlobalAveragePooling2D(),

    tf.keras.layers.Dropout(0.3),

    tf.keras.layers.Dense(num_classes, activation="softmax")
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │         5,124 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,263,108 (8.63 MB)
#  Trainable params: 5,124 (20.02 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=8,
    restore_best_weights=True
)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=100,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 172ms/step - accuracy: 0.2254 - loss: 1.8693 - val_accuracy: 0.1613 - val_loss: 1.7667
# Epoch 2/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.2535 - loss: 1.7716 - val_accuracy: 0.1613 - val_loss: 1.6807
# Epoch 3/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.2958 - loss: 1.7019 - val_accuracy: 0.2258 - val_loss: 1.6109
# Epoch 4/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.2465 - loss: 1.6337 - val_accuracy: 0.2581 - val_loss: 1.5587
# Epoch 5/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.2254 - loss: 1.5535 - val_accuracy: 0.2581 - val_loss: 1.5145
# Epoch 6/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.2746 - loss: 1.5459 - val_accuracy: 0.2903 - val_loss: 1.4771
# Epoch 7/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 0.3592 - loss: 1.4162 - val_accuracy: 0.2903 - val_loss: 1.4428
# Epoch 8/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - accuracy: 0.3169 - loss: 1.4765 - val_accuracy: 0.3548 - val_loss: 1.4049
# Epoch 9/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.3521 - loss: 1.4176 - val_accuracy: 0.3226 - val_loss: 1.3687
# Epoch 10/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 0.4296 - loss: 1.2283 - val_accuracy: 0.3548 - val_loss: 1.3358
# Epoch 11/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - accuracy: 0.4155 - loss: 1.2861 - val_accuracy: 0.3548 - val_loss: 1.3057
# Epoch 12/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.4296 - loss: 1.2761 - val_accuracy: 0.3548 - val_loss: 1.2785
# Epoch 13/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.4648 - loss: 1.1846 - val_accuracy: 0.3871 - val_loss: 1.2526
# Epoch 14/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.5282 - loss: 1.1482 - val_accuracy: 0.4194 - val_loss: 1.2276
# Epoch 15/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.4718 - loss: 1.2056 - val_accuracy: 0.4194 - val_loss: 1.2054
# Epoch 16/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.4789 - loss: 1.1908 - val_accuracy: 0.4516 - val_loss: 1.1837
# Epoch 17/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.5352 - loss: 1.0768 - val_accuracy: 0.4839 - val_loss: 1.1609
# Epoch 18/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - accuracy: 0.5775 - loss: 1.0369 - val_accuracy: 0.4839 - val_loss: 1.1422
# Epoch 19/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.4930 - loss: 1.0789 - val_accuracy: 0.4839 - val_loss: 1.1245
# Epoch 20/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - accuracy: 0.5000 - loss: 1.1145 - val_accuracy: 0.4839 - val_loss: 1.1091
# Epoch 21/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.5634 - loss: 1.0585 - val_accuracy: 0.5161 - val_loss: 1.0938
# Epoch 22/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.5704 - loss: 0.9911 - val_accuracy: 0.5161 - val_loss: 1.0779
# Epoch 23/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.5775 - loss: 0.9909 - val_accuracy: 0.5161 - val_loss: 1.0611
# Epoch 24/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.6549 - loss: 0.8817 - val_accuracy: 0.5161 - val_loss: 1.0463
# Epoch 25/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.6408 - loss: 0.9065 - val_accuracy: 0.5161 - val_loss: 1.0352
# Epoch 26/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.5986 - loss: 0.9138 - val_accuracy: 0.5161 - val_loss: 1.0218
# Epoch 27/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.6479 - loss: 0.8640 - val_accuracy: 0.5161 - val_loss: 1.0076
# Epoch 28/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.7042 - loss: 0.8150 - val_accuracy: 0.5484 - val_loss: 0.9992
# Epoch 29/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.6479 - loss: 0.8691 - val_accuracy: 0.5484 - val_loss: 0.9877
# Epoch 30/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.6338 - loss: 0.8244 - val_accuracy: 0.5484 - val_loss: 0.9802
# Epoch 31/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.6901 - loss: 0.8324 - val_accuracy: 0.5484 - val_loss: 0.9723
# Epoch 32/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.6972 - loss: 0.7613 - val_accuracy: 0.5484 - val_loss: 0.9637
# Epoch 33/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.6761 - loss: 0.8194 - val_accuracy: 0.5484 - val_loss: 0.9572
# Epoch 34/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.7042 - loss: 0.7586 - val_accuracy: 0.5484 - val_loss: 0.9474
# Epoch 35/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.7042 - loss: 0.7113 - val_accuracy: 0.5484 - val_loss: 0.9380
# Epoch 36/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 0.6831 - loss: 0.7870 - val_accuracy: 0.5484 - val_loss: 0.9288
# Epoch 37/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - accuracy: 0.7535 - loss: 0.7068 - val_accuracy: 0.5484 - val_loss: 0.9236
# Epoch 38/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.6690 - loss: 0.7709 - val_accuracy: 0.5484 - val_loss: 0.9176
# Epoch 39/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.7465 - loss: 0.7124 - val_accuracy: 0.5484 - val_loss: 0.9091
# Epoch 40/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - accuracy: 0.7606 - loss: 0.7044 - val_accuracy: 0.5484 - val_loss: 0.9020
# Epoch 41/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.7324 - loss: 0.6660 - val_accuracy: 0.5484 - val_loss: 0.8953
# Epoch 42/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.7183 - loss: 0.7357 - val_accuracy: 0.5484 - val_loss: 0.8907
# Epoch 43/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.8028 - loss: 0.6867 - val_accuracy: 0.5806 - val_loss: 0.8883
# Epoch 44/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.8310 - loss: 0.5752 - val_accuracy: 0.5806 - val_loss: 0.8817
# Epoch 45/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.7535 - loss: 0.6570 - val_accuracy: 0.5806 - val_loss: 0.8755
# Epoch 46/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - accuracy: 0.7324 - loss: 0.6746 - val_accuracy: 0.5806 - val_loss: 0.8694
# Epoch 47/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.8169 - loss: 0.6022 - val_accuracy: 0.5806 - val_loss: 0.8648
# Epoch 48/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.7254 - loss: 0.7199 - val_accuracy: 0.5806 - val_loss: 0.8622
# Epoch 49/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - accuracy: 0.7606 - loss: 0.5964 - val_accuracy: 0.5806 - val_loss: 0.8598
# Epoch 50/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - accuracy: 0.7254 - loss: 0.6446 - val_accuracy: 0.5806 - val_loss: 0.8556
# Epoch 51/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.7958 - loss: 0.5875 - val_accuracy: 0.5806 - val_loss: 0.8485
# Epoch 52/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.7746 - loss: 0.6584 - val_accuracy: 0.5806 - val_loss: 0.8419
# Epoch 53/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.7535 - loss: 0.6228 - val_accuracy: 0.6129 - val_loss: 0.8373
# Epoch 54/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.7606 - loss: 0.6399 - val_accuracy: 0.6129 - val_loss: 0.8349
# Epoch 55/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.8239 - loss: 0.5939 - val_accuracy: 0.6452 - val_loss: 0.8285
# Epoch 56/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.7676 - loss: 0.5976 - val_accuracy: 0.6129 - val_loss: 0.8265
# Epoch 57/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.7958 - loss: 0.5960 - val_accuracy: 0.6129 - val_loss: 0.8229
# Epoch 58/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.7817 - loss: 0.5798 - val_accuracy: 0.6452 - val_loss: 0.8150
# Epoch 59/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.7817 - loss: 0.5560 - val_accuracy: 0.6452 - val_loss: 0.8057
# Epoch 60/60
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.7887 - loss: 0.5432 - val_accuracy: 0.6452 - val_loss: 0.8038

# %%
plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.title("Transfer Learning Accuracy - MobileNetV2")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("Transfer Learning Loss - MobileNetV2")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()
