# %% [markdown]
# Now we will try to use transfer learning which is a model that was already trained on a huge image dataset and then adapt it to the smaller acne dataset
#
# basically instead of the model learning everything from 0 like we have been doing it will start pre-existing knowledge, such as, edges, colours, textures, curves, shapes, smaller patterns, and surface details
#
# Will try to use MobileNetV2 which is a lightweight pretrained CNN and commonly used for image classification
#
# How it works MNV2 works, it can be seen as two parts, pretrainted feature extractor + custom classifier
#
# the pretrained part will look at the imnage and extract useful features
#
# the custom classifier takes those features and predict one of the classes
#
# Need to freeze the base model which is MNV2, and freezing is not updated the pretrained models weights during training, this needs to be done specifically here since MNV2 already learned useful image features so if train everything immediately on the small dataset it might lose those learn features

# %%
from pathlib import Path
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
PROJECT_ROOT = Path("..")
PROCESSED_DIR = PROJECT_ROOT / "data" / "processed"

train_df = pd.read_csv(PROCESSED_DIR / "train.csv")
val_df = pd.read_csv(PROCESSED_DIR / "val.csv")
test_df = pd.read_csv(PROCESSED_DIR / "test.csv")

train_df.head()
# Out:
#                                original_path  \
# 0        ..\data\raw\acne_scars\scar_026.png
# 1  ..\data\raw\comedonal_closed\come_022.png
# 2   ..\data\raw\comedonal_open\comeo_035.png
# 3        ..\data\raw\acne_scars\scar_050.png
# 4  ..\data\raw\comedonal_closed\come_021.png
#
#                                       processed_path             label
# 0   ..\data\processed\acne_scars\acne_scars_0026.jpg        acne_scars
# 1  ..\data\processed\comedonal_closed\comedonal_c...  comedonal_closed
# 2  ..\data\processed\comedonal_open\comedonal_ope...    comedonal_open
# 3   ..\data\processed\acne_scars\acne_scars_0050.jpg        acne_scars
# 4  ..\data\processed\comedonal_closed\comedonal_c...  comedonal_closed

# %%
class_names = sorted(train_df["label"].unique())
label_to_index = {label: index for index, label in enumerate(class_names)}

train_df["label_index"] = train_df["label"].map(label_to_index)
val_df["label_index"] = val_df["label"].map(label_to_index)
test_df["label_index"] = test_df["label"].map(label_to_index)

class_names, label_to_index
# Out:
# (['acne_scars', 'comedonal_closed', 'comedonal_open', 'inflammatory_acne'],
#  {'acne_scars': 0,
#   'comedonal_closed': 1,
#   'comedonal_open': 2,
#   'inflammatory_acne': 3})

# %%
train_paths = train_df["processed_path"].values
val_paths = val_df["processed_path"].values
test_paths = test_df["processed_path"].values

train_labels = train_df["label_index"].values
val_labels = val_df["label_index"].values
test_labels = test_df["label_index"].values

# %%
IMG_SIZE = 224
BATCH_SIZE = 16

def load_image_for_mobilenet(image_path, label):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    image = tf.keras.applications.mobilenet_v2.preprocess_input(image)
    return image, label

# %%
train_ds = tf.data.Dataset.from_tensor_slices((train_paths, train_labels))
val_ds = tf.data.Dataset.from_tensor_slices((val_paths, val_labels))
test_ds = tf.data.Dataset.from_tensor_slices((test_paths, test_labels))

train_ds = train_ds.map(load_image_for_mobilenet)
val_ds = val_ds.map(load_image_for_mobilenet)
test_ds = test_ds.map(load_image_for_mobilenet)

train_ds = train_ds.shuffle(buffer_size=len(train_df)).batch(BATCH_SIZE)
val_ds = val_ds.batch(BATCH_SIZE)
test_ds = test_ds.batch(BATCH_SIZE)

# %%
## still going to use the gentle data augmentation
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.03),
    tf.keras.layers.RandomZoom(0.05),
])

# %%
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights="imagenet"
)

base_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
num_classes = len(class_names)

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(224, 224, 3)),
    data_augmentation,

    base_model,

    tf.keras.layers.GlobalAveragePooling2D(),

    tf.keras.layers.Dropout(0.3),

    tf.keras.layers.Dense(num_classes, activation="softmax")
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 4)              │         5,124 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,263,108 (8.63 MB)
#  Trainable params: 5,124 (20.02 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=4,
    restore_best_weights=True
)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 4s 168ms/step - accuracy: 0.2394 - loss: 1.9799 - val_accuracy: 0.0968 - val_loss: 1.8776
# Epoch 2/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.2113 - loss: 1.8642 - val_accuracy: 0.1290 - val_loss: 1.8025
# Epoch 3/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.2324 - loss: 1.7397 - val_accuracy: 0.1613 - val_loss: 1.7365
# Epoch 4/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.2535 - loss: 1.7701 - val_accuracy: 0.1613 - val_loss: 1.6740
# Epoch 5/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.2606 - loss: 1.6244 - val_accuracy: 0.1935 - val_loss: 1.6206
# Epoch 6/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.3099 - loss: 1.5741 - val_accuracy: 0.2258 - val_loss: 1.5694
# Epoch 7/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.3099 - loss: 1.4545 - val_accuracy: 0.2258 - val_loss: 1.5217
# Epoch 8/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.3732 - loss: 1.4066 - val_accuracy: 0.2581 - val_loss: 1.4779
# Epoch 9/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.3451 - loss: 1.4694 - val_accuracy: 0.2903 - val_loss: 1.4348
# Epoch 10/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.3873 - loss: 1.2688 - val_accuracy: 0.2903 - val_loss: 1.3938
# Epoch 11/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.4225 - loss: 1.2776 - val_accuracy: 0.3226 - val_loss: 1.3567
# Epoch 12/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.4085 - loss: 1.3308 - val_accuracy: 0.3548 - val_loss: 1.3222
# Epoch 13/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.4225 - loss: 1.2377 - val_accuracy: 0.3871 - val_loss: 1.2910
# Epoch 14/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.4648 - loss: 1.2041 - val_accuracy: 0.4194 - val_loss: 1.2602
# Epoch 15/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.4507 - loss: 1.2322 - val_accuracy: 0.4194 - val_loss: 1.2310
# Epoch 16/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.5141 - loss: 1.1402 - val_accuracy: 0.4194 - val_loss: 1.2033
# Epoch 17/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.5000 - loss: 1.1082 - val_accuracy: 0.4516 - val_loss: 1.1761
# Epoch 18/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.4648 - loss: 1.1422 - val_accuracy: 0.4516 - val_loss: 1.1508
# Epoch 19/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.5070 - loss: 1.1325 - val_accuracy: 0.4516 - val_loss: 1.1272
# Epoch 20/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.5352 - loss: 1.0566 - val_accuracy: 0.4839 - val_loss: 1.1050
# Epoch 21/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.5563 - loss: 1.0717 - val_accuracy: 0.4839 - val_loss: 1.0843
# Epoch 22/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.5563 - loss: 1.0238 - val_accuracy: 0.5806 - val_loss: 1.0638
# Epoch 23/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.5986 - loss: 1.0062 - val_accuracy: 0.5806 - val_loss: 1.0455
# Epoch 24/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.6268 - loss: 0.9660 - val_accuracy: 0.6129 - val_loss: 1.0283
# Epoch 25/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.5915 - loss: 0.9574 - val_accuracy: 0.6129 - val_loss: 1.0114
# Epoch 26/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.5775 - loss: 0.9091 - val_accuracy: 0.6129 - val_loss: 0.9950
# Epoch 27/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.6549 - loss: 0.8975 - val_accuracy: 0.6774 - val_loss: 0.9800
# Epoch 28/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.6479 - loss: 0.8704 - val_accuracy: 0.6774 - val_loss: 0.9666
# Epoch 29/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.5915 - loss: 0.9142 - val_accuracy: 0.6774 - val_loss: 0.9544
# Epoch 30/30
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.6408 - loss: 0.9155 - val_accuracy: 0.6774 - val_loss: 0.9427

# %%
plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.title("Transfer Learning Accuracy - MobileNetV2")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("Transfer Learning Loss - MobileNetV2")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()
